# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pdb
import os
import math
import pysam
import sys
import lockfile
from time import sleep

sys.path.append('/home/rt2776/cnv_espresso/src')
import function as func
import function_dl as func_dl
# Out:
# Tensorflow version 2.2.0

# %%
def generate_one_image(cnv_data_df, sge_task_id, col_dict, 
                        RD_norm_dir, ref_samples_dir, output_path, corr_threshold=-1, flanking=None):
    index = sge_task_id-1
    row   = cnv_data_df.iloc[index]
    col_sampleID       = col_dict['col_sampleID']
    col_cnv_interval   = col_dict['col_cnv_interval']
    col_cnv_chr        = col_dict['col_cnv_chr']
    col_cnv_start      = col_dict['col_cnv_start']
    col_cnv_end        = col_dict['col_cnv_end']
    col_cnv_type       = col_dict['col_cnv_type']
    col_cnv_num_targets= col_dict['col_cnv_num_targets']
    col_cnv_canoes     = col_dict['col_cnv_canoes']
    col_cnv_xhmm       = col_dict['col_cnv_xhmm']
    col_cnv_clamms     = col_dict['col_cnv_clamms']
    col_cnv_numCarriers= col_dict['col_cnv_numCarriers']
    col_GSD_label      = col_dict['col_GSD_label']
    col_PRE_label      = col_dict['col_PRE_label']

    output_EntireCNV_image_dir  = output_path 

    sampleID  = row[col_sampleID]
    try:
        cnv_interval = row[col_cnv_interval]
        cnv_chr, cnv_start, cnv_end = func.parseInterval(cnv_interval) 
    except:
        cnv_chr   = row[col_cnv_chr]
        cnv_start = int(row[col_cnv_start])
        cnv_end   = int(row[col_cnv_end])
    cnv_type  = row[col_cnv_type]

    if cnv_type == 1:
        cnv_type = "DEL"
    elif cnv_type == 3:
        cnv_type = "DUP"
    else:
        pass

    case_sample_color = color_del if cnv_type == 'DEL' else color_dup

    cnv_num_targets   = row[col_cnv_num_targets] if col_cnv_num_targets != None else 'NA'
    cnv_canoes        = str(row[col_cnv_canoes]) if col_cnv_canoes != None else 'NA'
    cnv_xhmm          = str(row[col_cnv_xhmm])   if col_cnv_xhmm   != None else 'NA'
    cnv_clamms        = str(row[col_cnv_clamms]) if col_cnv_clamms != None else 'NA'
    cnv_num_carriers  = str(row[col_cnv_numCarriers]) if col_cnv_numCarriers != None else 'NA'
    cnv_gsd_label     = row[col_GSD_label] if col_GSD_label != None else 'NA'
    cnv_CNLearn_label = row[col_PRE_label] if col_PRE_label != None else 'NA'

    if cnv_gsd_label == 'NA':
        cnv_gsd_str = 'NA'
    else:    
        if cnv_gsd_label == 1:
            cnv_gsd_str = "True"
        elif cnv_gsd_label == 0:
            cnv_gsd_str = "False"
        else:
            cnv_gsd_str = cnv_gsd_label 

    if cnv_CNLearn_label == 'NA':
        cnv_CNLearn_str = 'NA'
    else:    
        cnv_CNLearn_str = "True" if cnv_CNLearn_label == 1 else "False"

    print("[%d|%d] Illustrating: %s %s:%d-%d %s #targets:%s Label:%s"% \
           (len(cnv_data_df), index+1, sampleID, cnv_chr, cnv_start, cnv_end, cnv_type, str(cnv_num_targets), cnv_gsd_str))

    ## Confirm the boundries
    if flanking == True or flanking == 'True':
        cnv_length   = cnv_end - cnv_start + 1
        figure_left  = cnv_start - cnv_length/2
        figure_right = cnv_end + cnv_length/2
    else:
        figure_left  = cnv_start
        figure_right = cnv_end

    print(" Generate CNV %s:%d-%d %s with boundary located at %s:%d-%d"%(cnv_chr, cnv_start, cnv_end, cnv_type, 
                                                                        cnv_chr, figure_left, figure_right))
    ## Import RD data info
    print("  --Step1. Fetching RD data for case sample ...")
    RD_cnv_region_df = func.fetchRDdata_byTabix(RD_norm_dir, sampleID, cnv_chr, figure_left, figure_right, fixed_win_num)

    ## Fetch Read depth data for reference samples in terms of CNV boundary       
    print("  --Step2. Fetching RD data for reference samples ...")
    ref_samples_file = func.fetch_relative_file_path(ref_samples_dir, sampleID,'txt')

    if not os.path.exists(ref_samples_file):
        print("    -[Error]: error in reference samples related file for %s in %s"%(sampleID, ref_samples_dir))
        exit(0)
  
    reference_RD_df = func.fetchRefRDdata_byTabix(RD_norm_dir, ref_samples_file, 
                                                    cnv_chr, figure_left, figure_right, 
                                                    fixed_win_num, corr_threshold)

    ## plot the entire cnv into one image
    print("  --Step3. Illustrating an image for the entire CNV ...")
    title_info = sampleID+" "+str(cnv_chr)+":"+str(cnv_start)+"-"+str(cnv_end)+" "+cnv_type + \
                 " "+ str((cnv_end-cnv_start)/1000) + 'kb'+ " #targets:" + str(len(RD_cnv_region_df)) 

    image_file = str(index+1)+"_"+sampleID+"_"+str(cnv_chr)+"_"+str(cnv_start)+"_"+str(cnv_end) + \
                 "_"+str(cnv_num_targets)+"tgs_"+str(len(RD_cnv_region_df))+"wins_"+cnv_type+".pdf"

    fig = plt.figure(dpi=150,figsize=(10, 7)) 
    ax_rd = fig.subplots(nrows=1, ncols=1)

    ### plot reference samples
    for sample_reader in reference_RD_df["sample"].unique():
                ref_sample_df = reference_RD_df[reference_RD_df["sample"]==sample_reader]
                ax_rd.plot((ref_sample_df["start"]+ref_sample_df["end"])/2, ref_sample_df["RD_norm"],
                            color='grey', marker='.', linewidth=0.2)

    ### plot case sample
    ax_rd.plot((RD_cnv_region_df["start"]+RD_cnv_region_df["end"])/2, RD_cnv_region_df["RD_norm"], \
                color=case_sample_color , marker='o', linewidth=2)
    ax_rd.set_title(title_info)

    ### write the img path to the cnv_file_w_img_file
    print("  --Step4. Output image file to %s."%(output_EntireCNV_image_dir+image_file))
    img_path = output_EntireCNV_image_dir+image_file
    plt.savefig(img_path)
    plt.close()  
    print("  --[Done].")

# %%
RD_norm_dir     = '/home/rt2776/cnv_espresso/project1_pcgc/norm/'
ref_samples_dir = '/home/rt2776/cnv_espresso/project1_pcgc/ref_samples/'
cnv_file        = '/home/rt2776/cnv_espresso/project1_pcgc/images_new/pcgc_NimbleGenV2_data_withImagePath.csv'
output_path     = '/home/rt2776/cnv_espresso/project1_pcgc/'
cnv_data_df = pd.read_csv(cnv_file)
cnv_data_df
# Out:
#          ID Chr      Start        End         Band  CNV_TYPE  \
# 0   1-01401   1   59247993   59251097        p32.1         1
# 1   1-03171   1  145586403  145799634        q21.1         3
# 2   1-01036   1  146631133  147416212        q21.1         3
# 3   1-01486   1  194201171  194304070    q24.2–q25         3
# 4   1-01536   2   70168995   70359345        p13.3         1
# 5   1-01401   2  102493466  103001458  q11.2–q12.1         1
# 6   1-01401   2  145155868  145274931        q22.3         1
# 7   1-00762   3      60661   11712230        p26.1         3
# 8   1-01049   3   15637812   15643461        p25.1         3
# 9   1-01045   3   47780965   48309270       p21.31         3
# 10  1-02093   3  197143652  197186111          q29         3
# 11  1-00771   4  185603346  185638397        q34.1         1
# 12  1-00789   5     136464     232969       p15.33         3
# 13  1-00113   5  133706994  133730455        q31.1         1
# 14  1-00296   5  166386727  173073664    q34–q35.2         1
# 15  1-01916   6   36646788   36651971        p21.2         1
# 16  1-01049   6   43484783   43485159        p21.1         3
# 17  1-00096   7   50179707   50191153        p12.2         1
# 18  1-00977   7  138258252  143807632      q24–q25         1
# 19  1-01995   7  142334207  142460871          q34         1
# 20  1-01562   8    8067768   12530976  p22.1–p23.1         3
# 21  1-02625   8    8102183   12190106        p23.1         3
# 22  1-00566   8   11606428   11710963        p23.1         1
# 23  1-02360   9    5302500    5337760        p24.1         3
# 24  1-00565  11   42968283   42970488          p12         3
# 25  1-01536  11   65157239   65408708        q13.1         1
# 26  1-00230  11   86939592   87025456        q14.2         1
# 27  1-01486  11  125641368  134943190    q24.2–q25         1
# 28  1-02411  14   58860893   58881694        q23.1         1
# 29  1-01049  14   74551632   74551731        q24.3         3
# 30  1-00192  15   22296985   23161330        q11.2         3
# 31  1-00315  15   22750305   23140114        q11.2         3
# 32  1-01396  15   22750305   23228712        q11.2         1
# 33  1-00243  15   22835893   23062345        q11.2         1
# 34  1-01994  15   28389771   28446734        q13.2         1
# 35  1-01696  15   44833588   44856873        q21.1         1
# 36  1-01941  15   88761539   88779300        q25.3         3
# 37  1-01427  17   21562473   22252439        p11.2         1
# 38  1-00561  17   27962393   28099002        q11.2         1
# 39  1-01995  17   38544624   38548586        q21.1         1
# 40  1-01049  17   39845210   39846477        q21.2         3
# 41  1-02170  19   20601006   20717536          p12         1
# 42  1-00174  19   40515744   40681387        q13.2         1
# 43  1-01536  19   47792293   47905132       q13.33         1
# 44  1-00730  20   14529657   14583899        p12.2         1
# 45  1-00113  22   18886915   22000000        q11.2         1
# 46  1-01836  22   19020529   21380382        q11.2         1
# 47  1-02133  22   25661725   25919492       q11.23         3
# 48  1-00425  22   36038076   36149338        q12.3         1
# 49  1-01427  22   42522638   42531210        q13.2         3
# 50  1-01941   X   23003525   23086619       p22.11         3
# 51  1-00197   X  148685645  148693146          q28         3
#
#                                      Syndrome_or_Gene Technologies  \
# 0                                                 JUN            A
# 1                                 1q21.1,dup_or_GJA5‡          A,E
# 2                                 1q21.1,dup_or_GJA5‡            E
# 3                                               CDC73            A
# 4                                               PCBP1            A
# 5                                              MAP4K4            E
# 6                               Mowat-Wilson_or_ZEB2‡            E
# 7   ARL8B,ARPC4,CAMK1,CAV3,CRBN,EMC3,ITPR1,SEC13,S...            A
# 8                                           BTD,HACL1            E
# 9                           CDC25A,DHX30,MAP4,SMARCC1            A
# 10                                               BDH1            A
# 11                                      CENPU,PRIMPOL            E
# 12                      CCDC127,LRRC14B,PLEKHG4B,SDHA            A
# 13                                              UBE2B            A
# 14                                            NKX2.5‡            A
# 15                                             CDKN1A            A
# 16                                             POLR1C            E
# 17                                            C7orf72            E
# 18  C7orf55,FAM115A,LUC7L2,MKRN1,NDUFB2,UBN2,ZC3HA...            E
# 19                                     MTRNR2L6,PRSS1            E
# 20                                             GATA4‡            A
# 21                                             GATA4‡            A
# 22                                             GATA4‡          A,E
# 23                                          RLN1,RLN2            A
# 24                                           HNRNPKP3            A
# 25          EHBP1L1,LTBP3,MAP3K11,PCNXL3,SCYL1,SSSCA1            A
# 26                                            TMEM135          A,E
# 27                                  Jacobsen_or_ETS1‡          A,E
# 28                                      TIMM9,TOMM20L            A
# 29                                              LIN52            E
# 30                            1,MB,from,PW_or_CYFIP1‡            A
# 31                            1,MB,from,PW_or_CYFIP1‡            A
# 32                            1,MB,from,PW_or_CYFIP1‡          A,E
# 33                            1,MB,from,PW_or_CYFIP1‡            E
# 34                                              HERC2            E
# 35                                        EIF3J,SPG11          A,E
# 36                                              NTRK3            A
# 37                           FAM27L,FLJ36000,MTRNR2L1            A
# 38                                               SSH2            A
# 39                                              TOP2A          A,E
# 40                                               EIF1            E
# 41                                            ZNF826P            A
# 42                             ZNF546,ZNF780A,ZNF780B            A
# 43                                  C5AR1,C5AR2,DHX34            A
# 44                                MACROD2,MACROD2-IT1            A
# 45                                  DiGeorge_or_TBX1‡          A,E
# 46                                  DiGeorge_or_TBX1‡          A,E
# 47                          22q11,distal,duplication‡            A
# 48                                 APOL5,APOL6,RBFOX2          A,E
# 49                                             CYP2D6            A
# 50                                  DDX53,RP11-40F8.2            A
# 51                                           TMEM185A            E
#
#    CardiacLesion(Diagnosis) ParentOrigin Extracardiac  Genes_n  Size_kb  \
# 0                LVOT(HLHS)            -            -        1      3.1
# 1          CTD(TOF_or_APVS)            -            -        7    213.2
# 2                  CTD(TOF)            M            -       15    785.1
# 3                LVOT(HLHS)            -          Yes        0    102.9
# 4            CTD(TOF_or_PA)            -            -        5    190.4
# 5                LVOT(HLHS)            -            -        6    508.0
# 6                LVOT(HLHS)            -            -        1    119.1
# 7            ASD_or_PS(ASD)            -          Yes      103  11651.6
# 8                  CTD(TOF)            -            -        2      5.6
# 9                LVOT(HLHS)            -            -       14    528.3
# 10           CTD(TOF_or_PA)            -          Yes        0     42.5
# 11         CTD(DTGA_or_VSD)            P          Yes        2     35.1
# 12                 CTD(TOF)            -            -        4     96.5
# 13           CTD(TOF_or_PA)            -          Yes        1     23.5
# 14                 CTD(TOF)            M          Yes       53   6686.9
# 15                 HTX(HTX)            -            -        1      5.2
# 16                 CTD(TOF)            -            -        1      0.4
# 17           CTD(TOF_or_PA)            -          Yes        1     11.4
# 18                 CTD(TOF)            -            -      175   5549.4
# 19                 CTD(TOF)            M            -       15    126.7
# 20                 CTD(TOF)            -            -       75   4463.2
# 21                LVOT(CoA)            M          Yes       62   4087.9
# 22                 CTD(TOF)            -            -        6    104.5
# 23                 CTD(ASD)            -          Yes        3     35.3
# 24               LVOTO(ASD)            -            -        0      2.2
# 25           CTD(TOF_or_PA)            -            -       14    251.5
# 26                LVOT(ASD)            P          Yes        1     85.9
# 27               LVOT(HLHS)            P          Yes       73   9301.8
# 28                 CTD(TOF)            -            -        2     20.8
# 29                 CTD(TOF)            -            -        1      0.1
# 30                LVOT(CoA)            -            -       20    864.3
# 31                LVOT(CoA)            M            -        5    389.8
# 32           CTD(TOF_or_PA)            P            -        6    478.4
# 33                LVOT(CoA)            P          Yes        4    226.5
# 34                LVOT(ASD)            P            -        1     57.0
# 35  CTD(TriAtresia_or_DTGA)            -            -        2     23.3
# 36         CTD(TOF_or_DTGA)            P            -        1     17.8
# 37                 HTX(HTX)            -          Yes        7    690.0
# 38                LVOT(ASD)            -          Yes        3    136.6
# 39                 CTD(TOF)            -            -        1      4.0
# 40                 CTD(TOF)            -            -        2      1.3
# 41                 CTD(TOF)            -          Yes        1    116.5
# 42           CTD(TOF_or_PA)            -          Yes        4    165.6
# 43           CTD(TOF_or_PA)            -            -        3    112.8
# 44                CTD(DTGA)            -            -        2     54.2
# 45           CTD(TOF_or_PA)            P          Yes       96   3113.1
# 46                 CTD(TOF)            M            -       70   2359.9
# 47                 CTD(TOF)            -            -        4    257.8
# 48               LVOT(HLHS)            -            -        4    111.3
# 49                 HTX(HTX)            -          Yes        2      8.6
# 50         CTD(TOF_or_DTGA)            -            -        1     83.1
# 51               LVOT(HLHS)            -          Yes        1      7.5
#
#           ref               batch  Num_Targets_Wins  \
# 0        hg19         NimbleGenV2                 1
# 1        hg19         NimbleGenV2                50
# 2        hg19         NimbleGenV2                75
# 3        hg19         NimbleGenV2                 0
# 4        hg19         NimbleGenV2                 4
# 5        hg19         NimbleGenV2                52
# 6        hg19         NimbleGenV2                 9
# 7        hg19         NimbleGenV2               664
# 8        hg19         NimbleGenV2                 4
# 9        hg19         NimbleGenV2                69
# 10       hg19         NimbleGenV2                 0
# 11       hg19         NimbleGenV2                15
# 12       hg19         NimbleGenV2                29
# 13       hg19         NimbleGenV2                 6
# 14       hg19         NimbleGenV2               389
# 15       hg19         NimbleGenV2                 1
# 16       hg19         NimbleGenV2                 2
# 17       hg19         NimbleGenV2                 3
# 18       hg19         NimbleGenV2               674
# 19       hg19         NimbleGenV2                17
# 20       hg19         NimbleGenV2               176
# 21       hg19         NimbleGenV2               171
# 22       hg19         NimbleGenV2                26
# 23       hg19         NimbleGenV2                 3
# 24       hg19         NimbleGenV2                 0
# 25       hg19         NimbleGenV2               134
# 26       hg19         NimbleGenV2                 6
# 27       hg19         NimbleGenV2               473
# 28       hg19         NimbleGenV2                 8
# 29       hg19         NimbleGenV2                 1
# 30       hg19         NimbleGenV2                73
# 31       hg19         NimbleGenV2                63
# 32       hg19         NimbleGenV2                63
# 33       hg19         NimbleGenV2                61
# 34       hg19         NimbleGenV2                25
# 35       hg19         NimbleGenV2                 8
# 36       hg19         NimbleGenV2                 0
# 37       hg19         NimbleGenV2                 2
# 38       hg19         NimbleGenV2                12
# 39       hg19         NimbleGenV2                 6
# 40       hg19         NimbleGenV2                 3
# 41       hg19         NimbleGenV2                 0
# 42       hg19         NimbleGenV2                20
# 43       hg19         NimbleGenV2                22
# 44       hg19         NimbleGenV2                 0
# 45       hg19         NimbleGenV2               535
# 46       hg19         NimbleGenV2               453
# 47       hg19         NimbleGenV2                 6
# 48  hg19,hg38  Mosaic,NimbleGenV2                 9
# 49       hg19         NimbleGenV2                 9
# 50       hg19         NimbleGenV2                 3
# 51       hg19         NimbleGenV2                 3
#
#                                       entire_cnv_path  \
# 0   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 1   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 2   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 3   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 4   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 5   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 6   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 7   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 8   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 9   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 10  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 11  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 12  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 13  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 14  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 15  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 16  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 17  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 18  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 19  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 20  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 21  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 22  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 23  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 24  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 25  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 26  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 27  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 28  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 29  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 30  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 31  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 32  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 33  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 34  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 35  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 36  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 37  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 38  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 39  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 40  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 41  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 42  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 43  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 44  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 45  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 46  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 47  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 48  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 49  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 50  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 51  /home/rt2776/cnv_espresso/project1_pcgc/images...
#
#                                        split_cnv_path
# 0                                                 NaN
# 1   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 6   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 7   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 12  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 13  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 14  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 15                                                NaN
# 16  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 17  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 18  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 19  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 20  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 21  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 22  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 23  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 24                                                NaN
# 25  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 26  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 27  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 28  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 29                                                NaN
# 30  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 31  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 32  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 33  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 34  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 35  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 36                                                NaN
# 37  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 38  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 39  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 40  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 41                                                NaN
# 42  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 43  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 44                                                NaN
# 45  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 46  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 47  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 48  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 49  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 50  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 51  /home/rt2776/cnv_espresso/project1_pcgc/images...

# %%
## Output images and folders
output_EntireCNV_image_dir  = output_path 
os.makedirs(output_EntireCNV_image_dir, exist_ok=True)

## Variables
global_var_dict = func.global_variables()
SAMPLE          = global_var_dict['SAMPLE']
CNV_CHR         = global_var_dict['CNV_CHR']
CNV_START       = global_var_dict['CNV_START']
CNV_END         = global_var_dict['CNV_END']
CNV_INTERVAL    = global_var_dict['CNV_INTERVAL']
CNV_TYPE        = global_var_dict['CNV_TYPE']
NUM_TARGETS     = global_var_dict['NUM_TARGETS']
GSD_LABEL       = global_var_dict['CNV_LABEL']
PRE_LABEL       = global_var_dict['REF']

fixed_win_num = 3 # the number of targets per group
color_del, color_dup = (0,0,1), (0,0,1) #blue for three classes labels

## Parse header
cnv_data_header  = cnv_data_df.columns.tolist()
col_sampleID     = func.fetch_colName(SAMPLE, cnv_data_header)[0]
col_cnv_interval = func.fetch_colName(CNV_INTERVAL, cnv_data_header)[0]
col_cnv_chr      = func.fetch_colName(CNV_CHR, cnv_data_header)[0]
col_cnv_start    = func.fetch_colName(CNV_START, cnv_data_header)[0]
col_cnv_end      = func.fetch_colName(CNV_END, cnv_data_header)[0]
col_cnv_type     = func.fetch_colName(CNV_TYPE, cnv_data_header)[0]
col_GSD_label    = func.fetch_colName(GSD_LABEL, cnv_data_header)[0]
col_PRE_label    = func.fetch_colName(PRE_LABEL, cnv_data_header)[0]
col_cnv_canoes   = func.fetch_colName(['CANOES','CANOES_RT'], cnv_data_header)[0]
col_cnv_xhmm     = func.fetch_colName(['XHMM','XHMM_RT'], cnv_data_header)[0]
col_cnv_clamms   = func.fetch_colName(['CLAMMS','CLAMMS_RT'], cnv_data_header)[0]
col_cnv_num_targets = func.fetch_colName(NUM_TARGETS, cnv_data_header)[0]
col_cnv_numCarriers = func.fetch_colName(['Num_Carriers(inGivenCohort)'], cnv_data_header)[0]

col_dict = {
    'col_sampleID'     : col_sampleID,
    'col_cnv_interval' : col_cnv_interval,
    'col_cnv_chr'      : col_cnv_chr,
    'col_cnv_start'    : col_cnv_start,
    'col_cnv_end'      : col_cnv_end,
    'col_cnv_type'     : col_cnv_type,
    'col_cnv_num_targets': col_cnv_num_targets,
    'col_cnv_canoes'   : col_cnv_canoes,
    'col_cnv_xhmm'     : col_cnv_xhmm,
    'col_cnv_clamms'   : col_cnv_clamms,
    'col_cnv_numCarriers': col_cnv_numCarriers,
    'col_GSD_label'    : col_GSD_label,
    'col_PRE_label'    : col_PRE_label
}

# %%
cnv_data_df
# Out:
#          ID Chr      Start        End         Band  CNV_TYPE  \
# 0   1-01401   1   59247993   59251097        p32.1         1
# 1   1-03171   1  145586403  145799634        q21.1         3
# 2   1-01036   1  146631133  147416212        q21.1         3
# 3   1-01486   1  194201171  194304070    q24.2–q25         3
# 4   1-01536   2   70168995   70359345        p13.3         1
# 5   1-01401   2  102493466  103001458  q11.2–q12.1         1
# 6   1-01401   2  145155868  145274931        q22.3         1
# 7   1-00762   3      60661   11712230        p26.1         3
# 8   1-01049   3   15637812   15643461        p25.1         3
# 9   1-01045   3   47780965   48309270       p21.31         3
# 10  1-02093   3  197143652  197186111          q29         3
# 11  1-00771   4  185603346  185638397        q34.1         1
# 12  1-00789   5     136464     232969       p15.33         3
# 13  1-00113   5  133706994  133730455        q31.1         1
# 14  1-00296   5  166386727  173073664    q34–q35.2         1
# 15  1-01916   6   36646788   36651971        p21.2         1
# 16  1-01049   6   43484783   43485159        p21.1         3
# 17  1-00096   7   50179707   50191153        p12.2         1
# 18  1-00977   7  138258252  143807632      q24–q25         1
# 19  1-01995   7  142334207  142460871          q34         1
# 20  1-01562   8    8067768   12530976  p22.1–p23.1         3
# 21  1-02625   8    8102183   12190106        p23.1         3
# 22  1-00566   8   11606428   11710963        p23.1         1
# 23  1-02360   9    5302500    5337760        p24.1         3
# 24  1-00565  11   42968283   42970488          p12         3
# 25  1-01536  11   65157239   65408708        q13.1         1
# 26  1-00230  11   86939592   87025456        q14.2         1
# 27  1-01486  11  125641368  134943190    q24.2–q25         1
# 28  1-02411  14   58860893   58881694        q23.1         1
# 29  1-01049  14   74551632   74551731        q24.3         3
# 30  1-00192  15   22296985   23161330        q11.2         3
# 31  1-00315  15   22750305   23140114        q11.2         3
# 32  1-01396  15   22750305   23228712        q11.2         1
# 33  1-00243  15   22835893   23062345        q11.2         1
# 34  1-01994  15   28389771   28446734        q13.2         1
# 35  1-01696  15   44833588   44856873        q21.1         1
# 36  1-01941  15   88761539   88779300        q25.3         3
# 37  1-01427  17   21562473   22252439        p11.2         1
# 38  1-00561  17   27962393   28099002        q11.2         1
# 39  1-01995  17   38544624   38548586        q21.1         1
# 40  1-01049  17   39845210   39846477        q21.2         3
# 41  1-02170  19   20601006   20717536          p12         1
# 42  1-00174  19   40515744   40681387        q13.2         1
# 43  1-01536  19   47792293   47905132       q13.33         1
# 44  1-00730  20   14529657   14583899        p12.2         1
# 45  1-00113  22   18886915   22000000        q11.2         1
# 46  1-01836  22   19020529   21380382        q11.2         1
# 47  1-02133  22   25661725   25919492       q11.23         3
# 48  1-00425  22   36038076   36149338        q12.3         1
# 49  1-01427  22   42522638   42531210        q13.2         3
# 50  1-01941   X   23003525   23086619       p22.11         3
# 51  1-00197   X  148685645  148693146          q28         3
#
#                                      Syndrome_or_Gene Technologies  \
# 0                                                 JUN            A
# 1                                 1q21.1,dup_or_GJA5‡          A,E
# 2                                 1q21.1,dup_or_GJA5‡            E
# 3                                               CDC73            A
# 4                                               PCBP1            A
# 5                                              MAP4K4            E
# 6                               Mowat-Wilson_or_ZEB2‡            E
# 7   ARL8B,ARPC4,CAMK1,CAV3,CRBN,EMC3,ITPR1,SEC13,S...            A
# 8                                           BTD,HACL1            E
# 9                           CDC25A,DHX30,MAP4,SMARCC1            A
# 10                                               BDH1            A
# 11                                      CENPU,PRIMPOL            E
# 12                      CCDC127,LRRC14B,PLEKHG4B,SDHA            A
# 13                                              UBE2B            A
# 14                                            NKX2.5‡            A
# 15                                             CDKN1A            A
# 16                                             POLR1C            E
# 17                                            C7orf72            E
# 18  C7orf55,FAM115A,LUC7L2,MKRN1,NDUFB2,UBN2,ZC3HA...            E
# 19                                     MTRNR2L6,PRSS1            E
# 20                                             GATA4‡            A
# 21                                             GATA4‡            A
# 22                                             GATA4‡          A,E
# 23                                          RLN1,RLN2            A
# 24                                           HNRNPKP3            A
# 25          EHBP1L1,LTBP3,MAP3K11,PCNXL3,SCYL1,SSSCA1            A
# 26                                            TMEM135          A,E
# 27                                  Jacobsen_or_ETS1‡          A,E
# 28                                      TIMM9,TOMM20L            A
# 29                                              LIN52            E
# 30                            1,MB,from,PW_or_CYFIP1‡            A
# 31                            1,MB,from,PW_or_CYFIP1‡            A
# 32                            1,MB,from,PW_or_CYFIP1‡          A,E
# 33                            1,MB,from,PW_or_CYFIP1‡            E
# 34                                              HERC2            E
# 35                                        EIF3J,SPG11          A,E
# 36                                              NTRK3            A
# 37                           FAM27L,FLJ36000,MTRNR2L1            A
# 38                                               SSH2            A
# 39                                              TOP2A          A,E
# 40                                               EIF1            E
# 41                                            ZNF826P            A
# 42                             ZNF546,ZNF780A,ZNF780B            A
# 43                                  C5AR1,C5AR2,DHX34            A
# 44                                MACROD2,MACROD2-IT1            A
# 45                                  DiGeorge_or_TBX1‡          A,E
# 46                                  DiGeorge_or_TBX1‡          A,E
# 47                          22q11,distal,duplication‡            A
# 48                                 APOL5,APOL6,RBFOX2          A,E
# 49                                             CYP2D6            A
# 50                                  DDX53,RP11-40F8.2            A
# 51                                           TMEM185A            E
#
#    CardiacLesion(Diagnosis) ParentOrigin Extracardiac  Genes_n  Size_kb  \
# 0                LVOT(HLHS)            -            -        1      3.1
# 1          CTD(TOF_or_APVS)            -            -        7    213.2
# 2                  CTD(TOF)            M            -       15    785.1
# 3                LVOT(HLHS)            -          Yes        0    102.9
# 4            CTD(TOF_or_PA)            -            -        5    190.4
# 5                LVOT(HLHS)            -            -        6    508.0
# 6                LVOT(HLHS)            -            -        1    119.1
# 7            ASD_or_PS(ASD)            -          Yes      103  11651.6
# 8                  CTD(TOF)            -            -        2      5.6
# 9                LVOT(HLHS)            -            -       14    528.3
# 10           CTD(TOF_or_PA)            -          Yes        0     42.5
# 11         CTD(DTGA_or_VSD)            P          Yes        2     35.1
# 12                 CTD(TOF)            -            -        4     96.5
# 13           CTD(TOF_or_PA)            -          Yes        1     23.5
# 14                 CTD(TOF)            M          Yes       53   6686.9
# 15                 HTX(HTX)            -            -        1      5.2
# 16                 CTD(TOF)            -            -        1      0.4
# 17           CTD(TOF_or_PA)            -          Yes        1     11.4
# 18                 CTD(TOF)            -            -      175   5549.4
# 19                 CTD(TOF)            M            -       15    126.7
# 20                 CTD(TOF)            -            -       75   4463.2
# 21                LVOT(CoA)            M          Yes       62   4087.9
# 22                 CTD(TOF)            -            -        6    104.5
# 23                 CTD(ASD)            -          Yes        3     35.3
# 24               LVOTO(ASD)            -            -        0      2.2
# 25           CTD(TOF_or_PA)            -            -       14    251.5
# 26                LVOT(ASD)            P          Yes        1     85.9
# 27               LVOT(HLHS)            P          Yes       73   9301.8
# 28                 CTD(TOF)            -            -        2     20.8
# 29                 CTD(TOF)            -            -        1      0.1
# 30                LVOT(CoA)            -            -       20    864.3
# 31                LVOT(CoA)            M            -        5    389.8
# 32           CTD(TOF_or_PA)            P            -        6    478.4
# 33                LVOT(CoA)            P          Yes        4    226.5
# 34                LVOT(ASD)            P            -        1     57.0
# 35  CTD(TriAtresia_or_DTGA)            -            -        2     23.3
# 36         CTD(TOF_or_DTGA)            P            -        1     17.8
# 37                 HTX(HTX)            -          Yes        7    690.0
# 38                LVOT(ASD)            -          Yes        3    136.6
# 39                 CTD(TOF)            -            -        1      4.0
# 40                 CTD(TOF)            -            -        2      1.3
# 41                 CTD(TOF)            -          Yes        1    116.5
# 42           CTD(TOF_or_PA)            -          Yes        4    165.6
# 43           CTD(TOF_or_PA)            -            -        3    112.8
# 44                CTD(DTGA)            -            -        2     54.2
# 45           CTD(TOF_or_PA)            P          Yes       96   3113.1
# 46                 CTD(TOF)            M            -       70   2359.9
# 47                 CTD(TOF)            -            -        4    257.8
# 48               LVOT(HLHS)            -            -        4    111.3
# 49                 HTX(HTX)            -          Yes        2      8.6
# 50         CTD(TOF_or_DTGA)            -            -        1     83.1
# 51               LVOT(HLHS)            -          Yes        1      7.5
#
#           ref               batch  Num_Targets_Wins  \
# 0        hg19         NimbleGenV2                 1
# 1        hg19         NimbleGenV2                50
# 2        hg19         NimbleGenV2                75
# 3        hg19         NimbleGenV2                 0
# 4        hg19         NimbleGenV2                 4
# 5        hg19         NimbleGenV2                52
# 6        hg19         NimbleGenV2                 9
# 7        hg19         NimbleGenV2               664
# 8        hg19         NimbleGenV2                 4
# 9        hg19         NimbleGenV2                69
# 10       hg19         NimbleGenV2                 0
# 11       hg19         NimbleGenV2                15
# 12       hg19         NimbleGenV2                29
# 13       hg19         NimbleGenV2                 6
# 14       hg19         NimbleGenV2               389
# 15       hg19         NimbleGenV2                 1
# 16       hg19         NimbleGenV2                 2
# 17       hg19         NimbleGenV2                 3
# 18       hg19         NimbleGenV2               674
# 19       hg19         NimbleGenV2                17
# 20       hg19         NimbleGenV2               176
# 21       hg19         NimbleGenV2               171
# 22       hg19         NimbleGenV2                26
# 23       hg19         NimbleGenV2                 3
# 24       hg19         NimbleGenV2                 0
# 25       hg19         NimbleGenV2               134
# 26       hg19         NimbleGenV2                 6
# 27       hg19         NimbleGenV2               473
# 28       hg19         NimbleGenV2                 8
# 29       hg19         NimbleGenV2                 1
# 30       hg19         NimbleGenV2                73
# 31       hg19         NimbleGenV2                63
# 32       hg19         NimbleGenV2                63
# 33       hg19         NimbleGenV2                61
# 34       hg19         NimbleGenV2                25
# 35       hg19         NimbleGenV2                 8
# 36       hg19         NimbleGenV2                 0
# 37       hg19         NimbleGenV2                 2
# 38       hg19         NimbleGenV2                12
# 39       hg19         NimbleGenV2                 6
# 40       hg19         NimbleGenV2                 3
# 41       hg19         NimbleGenV2                 0
# 42       hg19         NimbleGenV2                20
# 43       hg19         NimbleGenV2                22
# 44       hg19         NimbleGenV2                 0
# 45       hg19         NimbleGenV2               535
# 46       hg19         NimbleGenV2               453
# 47       hg19         NimbleGenV2                 6
# 48  hg19,hg38  Mosaic,NimbleGenV2                 9
# 49       hg19         NimbleGenV2                 9
# 50       hg19         NimbleGenV2                 3
# 51       hg19         NimbleGenV2                 3
#
#                                       entire_cnv_path  \
# 0   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 1   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 2   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 3   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 4   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 5   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 6   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 7   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 8   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 9   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 10  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 11  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 12  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 13  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 14  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 15  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 16  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 17  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 18  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 19  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 20  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 21  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 22  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 23  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 24  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 25  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 26  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 27  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 28  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 29  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 30  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 31  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 32  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 33  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 34  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 35  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 36  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 37  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 38  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 39  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 40  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 41  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 42  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 43  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 44  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 45  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 46  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 47  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 48  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 49  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 50  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 51  /home/rt2776/cnv_espresso/project1_pcgc/images...
#
#                                        split_cnv_path
# 0                                                 NaN
# 1   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 6   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 7   /home/rt2776/cnv_espresso/project1_pcgc/images...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 12  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 13  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 14  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 15                                                NaN
# 16  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 17  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 18  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 19  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 20  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 21  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 22  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 23  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 24                                                NaN
# 25  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 26  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 27  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 28  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 29                                                NaN
# 30  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 31  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 32  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 33  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 34  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 35  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 36                                                NaN
# 37  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 38  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 39  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 40  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 41                                                NaN
# 42  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 43  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 44                                                NaN
# 45  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 46  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 47  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 48  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 49  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 50  /home/rt2776/cnv_espresso/project1_pcgc/images...
# 51  /home/rt2776/cnv_espresso/project1_pcgc/images...

# %%
print(RD_norm_dir)
#print(cnv_info_w_img_file)
print(ref_samples_dir)
print(output_path)
# Out:
# /home/rt2776/cnv_espresso/project1_pcgc/norm/
# /home/rt2776/cnv_espresso/project1_pcgc/ref_samples/
# /home/rt2776/cnv_espresso/project1_pcgc/

# %%
# Figure 2a
generate_one_image(cnv_data_df, 39, col_dict, RD_norm_dir, ref_samples_dir, output_path)
# Out:
# [52|39] Illustrating: 1-00561 17:27962393-28099002 DEL #targets:NA Label:NA
#  Generate CNV 17:27962393-28099002 DEL with boundary located at 17:27962393-28099002
#   --Step1. Fetching RD data for case sample ...
#   --Step2. Fetching RD data for reference samples ...
#   --Step3. Illustrating an image for the entire CNV ...
#   --Step4. Output image file to /home/rt2776/cnv_espresso/project1_pcgc/39_1-00561_17_27962393_28099002_NAtgs_12wins_DEL.pdf.
#   --[Done].

# %%
# Figure 2b
generate_one_image(cnv_data_df, 50, col_dict, RD_norm_dir, ref_samples_dir, output_path)
# Out:
# [52|50] Illustrating: 1-01427 22:42522638-42531210 DUP #targets:NA Label:NA
#  Generate CNV 22:42522638-42531210 DUP with boundary located at 22:42522638-42531210
#   --Step1. Fetching RD data for case sample ...
#   --Step2. Fetching RD data for reference samples ...
#   --Step3. Illustrating an image for the entire CNV ...
#   --Step4. Output image file to /home/rt2776/cnv_espresso/project1_pcgc/50_1-01427_22_42522638_42531210_NAtgs_9wins_DUP.pdf.
#   --[Done].
